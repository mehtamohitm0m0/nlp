# %% [markdown]
# # Preprocessing of text using spacy

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc1=nlp('THE WRITING was on the wall — as early as almost half a century ago, when an 18-member committee warned that the town of Joshimath is “geologically unstable”, and suggested several restrictions and remedial measures. The committee, under the chairmanship of then Commissioner, Garhwal Mandal, Mahesh Chandra Mishra, was set up to probe the cause of landslides and sinking of Joshimath town. In its report dated May 7, 1976, it suggested restrictions on heavy construction work, agriculture on slopes, felling of trees; construction of pucca drainage to stop seepage of rainwater, proper sewage system, and cement blocks on river banks to prevent erosion.Amid the current crisis, the Congress and BJP are now blaming each other for failing to implement the recommendations of the report.')

# %%
type(doc1)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ## Tokenization

# %%
for token in doc1:
    print(token)
# Out:
# THE
# WRITING
# was
# on
# the
# wall
# —
# as
# early
# as
# almost
# half
# a
# century
# ago
# ,
# when
# an
# 18
# -
# member
# committee
# warned
# that
# the
# town
# of
# Joshimath
# is
# “
# geologically
# unstable
# ”
# ,
# and
# suggested
# several
# restrictions
# and
# remedial
# measures
# .
# The
# committee
# ,
# under
# the
# chairmanship
# of
# then
# Commissioner
# ,
# Garhwal
# Mandal
# ,
# Mahesh
# Chandra
# Mishra
# ,
# was
# set
# up
# to
# probe
# the
# cause
# of
# landslides
# and
# sinking
# of
# Joshimath
# town
# .
# In
# its
# report
# dated
# May
# 7
# ,
# 1976
# ,
# it
# suggested
# restrictions
# on
# heavy
# construction
# work
# ,
# agriculture
# on
# slopes
# ,
# felling
# of
# trees
# ;
# construction
# of
# pucca
# drainage
# to
# stop
# seepage
# of
# rainwater
# ,
# proper
# sewage
# system
# ,
# and
# cement
# blocks
# on
# river
# banks
# to
# prevent
# erosion
# .
# Amid
# the
# current
# crisis
# ,
# the
# Congress
# and
# BJP
# are
# now
# blaming
# each
# other
# for
# failing
# to
# implement
# the
# recommendations
# of
# the
# report
# .

# %%
# No of tokens

t_count=0
for token in doc1:
    t_count=t_count+1
    print(token)
print('\n\n The no of tokens:',t_count)
# Out:
# THE
# WRITING
# was
# on
# the
# wall
# —
# as
# early
# as
# almost
# half
# a
# century
# ago
# ,
# when
# an
# 18
# -
# member
# committee
# warned
# that
# the
# town
# of
# Joshimath
# is
# “
# geologically
# unstable
# ”
# ,
# and
# suggested
# several
# restrictions
# and
# remedial
# measures
# .
# The
# committee
# ,
# under
# the
# chairmanship
# of
# then
# Commissioner
# ,
# Garhwal
# Mandal
# ,
# Mahesh
# Chandra
# Mishra
# ,
# was
# set
# up
# to
# probe
# the
# cause
# of
# landslides
# and
# sinking
# of
# Joshimath
# town
# .
# In
# its
# report
# dated
# May
# 7
# ,
# 1976
# ,
# it
# suggested
# restrictions
# on
# heavy
# construction
# work
# ,
# agriculture
# on
# slopes
# ,
# felling
# of
# trees
# ;
# construction
# of
# pucca
# drainage
# to
# stop
# seepage
# of
# rainwater
# ,
# proper
# sewage
# system
# ,
# and
# cement
# blocks
# on
# river
# banks
# to
# prevent
# erosion
# .
# Amid
# the
# current
# crisis
# ,
# the
# Congress
# and
# BJP
# are
# now
# blaming
# each
# other
# for
# failing
# to
# implement
# the
# recommendations
# of
# the
# report
# .
#
#
#  The no of tokens: 147

# %%
len(doc1)
# Out:
# 147

# %% [markdown]
# ## Is it stop word

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'for', 'itself', 'nevertheless', 'about', 'still', 'name', 'always', '‘m', 'wherein', 'thus', "'d", "'m", 'really', 'say', 'everyone', 'does', 'anywhere', 'around', 'have', 'with', 'will', 'those', 'everything', 'over', 'my', '‘re', 'them', 'your', 'next', 'almost', '‘ll', 'seemed', 'should', 'top', 'now', 'more', 'formerly', 'beforehand', 'n’t', 'had', 'forty', 'latterly', 'onto', 'ours', 'as', 'used', 'none', 'who', 'unless', 'move', 'if', 'meanwhile', 'somehow', 'you', 'down', 'empty', 'any', 'between', 'others', 'once', 'many', 'these', 'eight', 'further', 'thereafter', 'give', 'rather', 'mostly', 'toward', 'may', 'whenever', 'yet', 'is', 'anyway', '’s', 'whereas', 'even', 'bottom', 'he', 'when', 'the', 'too', 'n‘t', 'our', 'or', 'nobody', 'sometime', 'no', 'twelve', 'nothing', 'see', 'but', 'on', 'thru', 'very', 'enough', 'also', 'such', 'something', 'each', 'whence', '‘s', 'why', 'every', 'this', 'we', 'nowhere', 'whoever', 'else', 'regarding', 'everywhere', 'nor', 'mine', 'yourselves', 'much', 'just', 'anyhow', 'except', 'must', 'moreover', 'became', 'themselves', "'re", 'seems', 'across', 'which', 'i', 'ca', 'several', 'sometimes', 'in', 'within', 'that', 'please', 'otherwise', 'either', 'could', 'besides', 'someone', 'somewhere', 'off', 'already', 'same', 'keep', 'most', 'be', 'to', 'thereby', 'ever', 'she', 'latter', 'noone', 'hundred', 'whereafter', 'me', 'ourselves', 'before', 'done', 'whose', 'go', 'its', 'by', 'only', 'seeming', 'least', 'her', 'through', 'becomes', 'him', 'where', 'above', 'front', 'beside', 'throughout', 'might', 'side', 'us', 'of', '’m', 'hereupon', 'last', 'whom', 'few', 'his', 'become', 'they', 'nine', 'back', 'was', 'yours', 'quite', '‘ve', 'never', 'get', 'using', 'it', 'perhaps', '’ve', 'ten', 'during', 'six', 'at', 'not', 'fifteen', 'did', 'herein', 'together', 'there', 'after', 'among', 'being', 'made', 'and', 'along', 'from', 'call', 'towards', 'full', 'various', 'neither', 'been', 'eleven', "'ve", 'herself', 'their', 'can', 'so', 'would', 'seem', 'a', 'therefore', 'beyond', 'show', 'some', 'what', 'thereupon', 'another', 'due', '’d', 'whole', 'first', 'all', 'up', 'sixty', 'here', 'because', 'anything', 'namely', 'whither', '’ll', 'amongst', 'below', 'under', 'against', 'yourself', 'afterwards', 'four', 'until', 'per', "'ll", 'amount', 'hereby', 'than', 'though', 'has', 'via', 'thence', 'wherever', 'were', 'cannot', 'doing', 'take', 'both', 'former', 'becoming', 'out', 'myself', 're', 'whereby', 'himself', 'anyone', 'while', 'an', 'although', 'indeed', 'hers', 'however', 'behind', 'again', 'often', 'am', 'own', "'s", 'elsewhere', 'whether', 'hereafter', 'fifty', 'since', '‘d', 'other', 'hence', 'third', 'part', 'then', '’re', 'do', 'five', 'make', 'are', 'into', 'without', 'how', 'whatever', "n't", 'alone', 'twenty', 'therein', 'one', 'serious', 'upon', 'well', 'two', 'less', 'whereupon', 'put', 'three'}

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
# No of stop words in the documnt

s_count=0
for token in doc1:
    print(token,'==>',token.is_stop)
print('\n \n The non- stop words in the doc \n')
for token in doc1:
    if token.is_stop == False:
        s_count=s_count+1
        print(token)
print('\n The no of non-stop words:',s_count)
# Out:
# THE ==> True
# WRITING ==> False
# was ==> True
# on ==> True
# the ==> True
# wall ==> False
# — ==> False
# as ==> True
# early ==> False
# as ==> True
# almost ==> True
# half ==> False
# a ==> True
# century ==> False
# ago ==> False
# , ==> False
# when ==> True
# an ==> True
# 18 ==> False
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> True
# the ==> True
# town ==> False
# of ==> True
# Joshimath ==> False
# is ==> True
# “ ==> False
# geologically ==> False
# unstable ==> False
# ” ==> False
# , ==> False
# and ==> True
# suggested ==> False
# several ==> True
# restrictions ==> False
# and ==> True
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> True
# committee ==> False
# , ==> False
# under ==> True
# the ==> True
# chairmanship ==> False
# of ==> True
# then ==> True
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> True
# set ==> False
# up ==> True
# to ==> True
# probe ==> False
# the ==> True
# cause ==> False
# of ==> True
# landslides ==> False
# and ==> True
# sinking ==> False
# of ==> True
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> True
# its ==> True
# report ==> False
# dated ==> False
# May ==> True
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> True
# suggested ==> False
# restrictions ==> False
# on ==> True
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> True
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> True
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> True
# pucca ==> False
# drainage ==> False
# to ==> True
# stop ==> False
# seepage ==> False
# of ==> True
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> True
# cement ==> False
# blocks ==> False
# on ==> True
# river ==> False
# banks ==> False
# to ==> True
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> True
# current ==> False
# crisis ==> False
# , ==> False
# the ==> True
# Congress ==> False
# and ==> True
# BJP ==> False
# are ==> True
# now ==> True
# blaming ==> False
# each ==> True
# other ==> True
# for ==> True
# failing ==> False
# to ==> True
# implement ==> False
# the ==> True
# recommendations ==> False
# of ==> True
# the ==> True
# report ==> False
# . ==> False
#
#
#  The non- stop words in the doc
#
# WRITING
# wall
# —
# early
# half
# century
# ago
# ,
# 18
# -
# member
# committee
# warned
# town
# Joshimath
# “
# geologically
# unstable
# ”
# ,
# suggested
# restrictions
# remedial
# measures
# .
# committee
# ,
# chairmanship
# Commissioner
# ,
# Garhwal
# Mandal
# ,
# Mahesh
# Chandra
# Mishra
# ,
# set
# probe
# cause
# landslides
# sinking
# Joshimath
# town
# .
# report
# dated
# 7
# ,
# 1976
# ,
# suggested
# restrictions
# heavy
# construction
# work
# ,
# agriculture
# slopes
# ,
# felling
# trees
# ;
# construction
# pucca
# drainage
# stop
# seepage
# rainwater
# ,
# proper
# sewage
# system
# ,
# cement
# blocks
# river
# banks
# prevent
# erosion
# .
# Amid
# current
# crisis
# ,
# Congress
# BJP
# blaming
# failing
# implement
# recommendations
# report
# .
#
#  The no of non-stop words: 93

# %% [markdown]
# ## Is it a punctuation

# %%
# No of non - punctations in the documnt

p_count=0
for token in doc1:
    print(token,'==>',token.is_punct)
print('\n \n The non- punctuations in the doc \n')
for token in doc1:
    if token.is_punct == False:
        p_count=p_count+1
        print(token)
print('\n The no of non-punctuations:',p_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> True
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> True
# when ==> False
# an ==> False
# 18 ==> False
# - ==> True
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> True
# geologically ==> False
# unstable ==> False
# ” ==> True
# , ==> True
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> True
# The ==> False
# committee ==> False
# , ==> True
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> True
# Garhwal ==> False
# Mandal ==> False
# , ==> True
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> True
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> True
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> False
# , ==> True
# 1976 ==> False
# , ==> True
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> True
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> True
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> True
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> True
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> True
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> True
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> True
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> True
#
#
#  The non- punctuations in the doc
#
# THE
# WRITING
# was
# on
# the
# wall
# as
# early
# as
# almost
# half
# a
# century
# ago
# when
# an
# 18
# member
# committee
# warned
# that
# the
# town
# of
# Joshimath
# is
# geologically
# unstable
# and
# suggested
# several
# restrictions
# and
# remedial
# measures
# The
# committee
# under
# the
# chairmanship
# of
# then
# Commissioner
# Garhwal
# Mandal
# Mahesh
# Chandra
# Mishra
# was
# set
# up
# to
# probe
# the
# cause
# of
# landslides
# and
# sinking
# of
# Joshimath
# town
# In
# its
# report
# dated
# May
# 7
# 1976
# it
# suggested
# restrictions
# on
# heavy
# construction
# work
# agriculture
# on
# slopes
# felling
# of
# trees
# construction
# of
# pucca
# drainage
# to
# stop
# seepage
# of
# rainwater
# proper
# sewage
# system
# and
# cement
# blocks
# on
# river
# banks
# to
# prevent
# erosion
# Amid
# the
# current
# crisis
# the
# Congress
# and
# BJP
# are
# now
# blaming
# each
# other
# for
# failing
# to
# implement
# the
# recommendations
# of
# the
# report
#
#  The no of non-punctuations: 125

# %% [markdown]
# ## Is it a left puncutation

# %%
# No of left - punctations in the documnt

lp_count=0
for token in doc1:
    print(token,'==>',token.is_left_punct)
print('\n \n The left punctuations in the doc \n')
for token in doc1:
    if token.is_left_punct == True:
        lp_count=lp_count+1
        print(token)
print('\n The no of left punctuations:',lp_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> False
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> True
# geologically ==> False
# unstable ==> False
# ” ==> False
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> False
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The left punctuations in the doc
#
# “
#
#  The no of left punctuations: 1

# %% [markdown]
# ## Is it a right punctuation

# %%
# No of right - punctations in the documnt

rp_count=0
for token in doc1:
    print(token,'==>',token.is_right_punct)
print('\n \n The right punctuations in the doc \n')
for token in doc1:
    if token.is_right_punct == True:
        rp_count=rp_count+1
        print(token)
print('\n The no of right punctuations:',rp_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> False
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> False
# geologically ==> False
# unstable ==> False
# ” ==> True
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> False
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The right punctuations in the doc
#
# ”
#
#  The no of right punctuations: 1

# %% [markdown]
# ## Is it an alphabet

# %%
# No of alphabets in the documnt

a_count=0
for token in doc1:
    print(token,'==>',token.is_alpha)
print('\n \n The alphabets in the doc \n')
for token in doc1:
    if token.is_alpha == True:
        a_count=a_count+1
        print(token)
print('\n The no of alphabets:',a_count)
# Out:
# THE ==> True
# WRITING ==> True
# was ==> True
# on ==> True
# the ==> True
# wall ==> True
# — ==> False
# as ==> True
# early ==> True
# as ==> True
# almost ==> True
# half ==> True
# a ==> True
# century ==> True
# ago ==> True
# , ==> False
# when ==> True
# an ==> True
# 18 ==> False
# - ==> False
# member ==> True
# committee ==> True
# warned ==> True
# that ==> True
# the ==> True
# town ==> True
# of ==> True
# Joshimath ==> True
# is ==> True
# “ ==> False
# geologically ==> True
# unstable ==> True
# ” ==> False
# , ==> False
# and ==> True
# suggested ==> True
# several ==> True
# restrictions ==> True
# and ==> True
# remedial ==> True
# measures ==> True
# . ==> False
# The ==> True
# committee ==> True
# , ==> False
# under ==> True
# the ==> True
# chairmanship ==> True
# of ==> True
# then ==> True
# Commissioner ==> True
# , ==> False
# Garhwal ==> True
# Mandal ==> True
# , ==> False
# Mahesh ==> True
# Chandra ==> True
# Mishra ==> True
# , ==> False
# was ==> True
# set ==> True
# up ==> True
# to ==> True
# probe ==> True
# the ==> True
# cause ==> True
# of ==> True
# landslides ==> True
# and ==> True
# sinking ==> True
# of ==> True
# Joshimath ==> True
# town ==> True
# . ==> False
# In ==> True
# its ==> True
# report ==> True
# dated ==> True
# May ==> True
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> True
# suggested ==> True
# restrictions ==> True
# on ==> True
# heavy ==> True
# construction ==> True
# work ==> True
# , ==> False
# agriculture ==> True
# on ==> True
# slopes ==> True
# , ==> False
# felling ==> True
# of ==> True
# trees ==> True
# ; ==> False
# construction ==> True
# of ==> True
# pucca ==> True
# drainage ==> True
# to ==> True
# stop ==> True
# seepage ==> True
# of ==> True
# rainwater ==> True
# , ==> False
# proper ==> True
# sewage ==> True
# system ==> True
# , ==> False
# and ==> True
# cement ==> True
# blocks ==> True
# on ==> True
# river ==> True
# banks ==> True
# to ==> True
# prevent ==> True
# erosion ==> True
# . ==> False
# Amid ==> True
# the ==> True
# current ==> True
# crisis ==> True
# , ==> False
# the ==> True
# Congress ==> True
# and ==> True
# BJP ==> True
# are ==> True
# now ==> True
# blaming ==> True
# each ==> True
# other ==> True
# for ==> True
# failing ==> True
# to ==> True
# implement ==> True
# the ==> True
# recommendations ==> True
# of ==> True
# the ==> True
# report ==> True
# . ==> False
#
#
#  The alphabets in the doc
#
# THE
# WRITING
# was
# on
# the
# wall
# as
# early
# as
# almost
# half
# a
# century
# ago
# when
# an
# member
# committee
# warned
# that
# the
# town
# of
# Joshimath
# is
# geologically
# unstable
# and
# suggested
# several
# restrictions
# and
# remedial
# measures
# The
# committee
# under
# the
# chairmanship
# of
# then
# Commissioner
# Garhwal
# Mandal
# Mahesh
# Chandra
# Mishra
# was
# set
# up
# to
# probe
# the
# cause
# of
# landslides
# and
# sinking
# of
# Joshimath
# town
# In
# its
# report
# dated
# May
# it
# suggested
# restrictions
# on
# heavy
# construction
# work
# agriculture
# on
# slopes
# felling
# of
# trees
# construction
# of
# pucca
# drainage
# to
# stop
# seepage
# of
# rainwater
# proper
# sewage
# system
# and
# cement
# blocks
# on
# river
# banks
# to
# prevent
# erosion
# Amid
# the
# current
# crisis
# the
# Congress
# and
# BJP
# are
# now
# blaming
# each
# other
# for
# failing
# to
# implement
# the
# recommendations
# of
# the
# report
#
#  The no of alphabets: 122

# %% [markdown]
# ## Is it a digit?

# %%
# No of digits in the documnt

d_count=0
for token in doc1:
    print(token,'==>',token.is_digit)
print('\n \n The digits in the doc \n')
for token in doc1:
    if token.is_digit == True:
        d_count=d_count+1
        print(token)
print('\n The no of digits:',d_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> True
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> False
# geologically ==> False
# unstable ==> False
# ” ==> False
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> False
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> True
# , ==> False
# 1976 ==> True
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The digits in the doc
#
# 18
# 7
# 1976
#
#  The no of digits: 3

# %% [markdown]
# ## Is it of lower case?

# %%
# No of lower cases in the documnt

l_count=0
for token in doc1:
    print(token,'==>',token.is_lower)
print('\n \n The lower cases in the doc \n')
for token in doc1:
    if token.is_lower == True:
        l_count=l_count+1
        print(token)
print('\n The no of lower case tokens:',l_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> True
# on ==> True
# the ==> True
# wall ==> True
# — ==> False
# as ==> True
# early ==> True
# as ==> True
# almost ==> True
# half ==> True
# a ==> True
# century ==> True
# ago ==> True
# , ==> False
# when ==> True
# an ==> True
# 18 ==> False
# - ==> False
# member ==> True
# committee ==> True
# warned ==> True
# that ==> True
# the ==> True
# town ==> True
# of ==> True
# Joshimath ==> False
# is ==> True
# “ ==> False
# geologically ==> True
# unstable ==> True
# ” ==> False
# , ==> False
# and ==> True
# suggested ==> True
# several ==> True
# restrictions ==> True
# and ==> True
# remedial ==> True
# measures ==> True
# . ==> False
# The ==> False
# committee ==> True
# , ==> False
# under ==> True
# the ==> True
# chairmanship ==> True
# of ==> True
# then ==> True
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> True
# set ==> True
# up ==> True
# to ==> True
# probe ==> True
# the ==> True
# cause ==> True
# of ==> True
# landslides ==> True
# and ==> True
# sinking ==> True
# of ==> True
# Joshimath ==> False
# town ==> True
# . ==> False
# In ==> False
# its ==> True
# report ==> True
# dated ==> True
# May ==> False
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> True
# suggested ==> True
# restrictions ==> True
# on ==> True
# heavy ==> True
# construction ==> True
# work ==> True
# , ==> False
# agriculture ==> True
# on ==> True
# slopes ==> True
# , ==> False
# felling ==> True
# of ==> True
# trees ==> True
# ; ==> False
# construction ==> True
# of ==> True
# pucca ==> True
# drainage ==> True
# to ==> True
# stop ==> True
# seepage ==> True
# of ==> True
# rainwater ==> True
# , ==> False
# proper ==> True
# sewage ==> True
# system ==> True
# , ==> False
# and ==> True
# cement ==> True
# blocks ==> True
# on ==> True
# river ==> True
# banks ==> True
# to ==> True
# prevent ==> True
# erosion ==> True
# . ==> False
# Amid ==> False
# the ==> True
# current ==> True
# crisis ==> True
# , ==> False
# the ==> True
# Congress ==> False
# and ==> True
# BJP ==> False
# are ==> True
# now ==> True
# blaming ==> True
# each ==> True
# other ==> True
# for ==> True
# failing ==> True
# to ==> True
# implement ==> True
# the ==> True
# recommendations ==> True
# of ==> True
# the ==> True
# report ==> True
# . ==> False
#
#
#  The lower cases in the doc
#
# was
# on
# the
# wall
# as
# early
# as
# almost
# half
# a
# century
# ago
# when
# an
# member
# committee
# warned
# that
# the
# town
# of
# is
# geologically
# unstable
# and
# suggested
# several
# restrictions
# and
# remedial
# measures
# committee
# under
# the
# chairmanship
# of
# then
# was
# set
# up
# to
# probe
# the
# cause
# of
# landslides
# and
# sinking
# of
# town
# its
# report
# dated
# it
# suggested
# restrictions
# on
# heavy
# construction
# work
# agriculture
# on
# slopes
# felling
# of
# trees
# construction
# of
# pucca
# drainage
# to
# stop
# seepage
# of
# rainwater
# proper
# sewage
# system
# and
# cement
# blocks
# on
# river
# banks
# to
# prevent
# erosion
# the
# current
# crisis
# the
# and
# are
# now
# blaming
# each
# other
# for
# failing
# to
# implement
# the
# recommendations
# of
# the
# report
#
#  The no of lower case tokens: 106

# %% [markdown]
# ## Is it in upper case?

# %%
# No of upper cases tokens in the documnt

u_count=0
for token in doc1:
    print(token,'==>',token.is_upper)
print('\n \n The upper case tokens in the doc \n')
for token in doc1:
    if token.is_upper == True:
        u_count=u_count+1
        print(token)
print('\n The no of upper case tokens:',u_count)
# Out:
# THE ==> True
# WRITING ==> True
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> False
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> False
# geologically ==> False
# unstable ==> False
# ” ==> False
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> False
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> True
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The upper case tokens in the doc
#
# THE
# WRITING
# BJP
#
#  The no of upper case tokens: 3

# %% [markdown]
# ## Is it a title case?

# %%
# No of title cases in the documnt

t_count=0
for token in doc1:
    print(token,'==>',token.is_title)
print('\n \n The title cases in the doc \n')
for token in doc1:
    if token.is_title == True:
        t_count=t_count+1
        print(token)
print('\n The no of title cases:',t_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> False
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> True
# is ==> False
# “ ==> False
# geologically ==> False
# unstable ==> False
# ” ==> False
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> True
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> True
# , ==> False
# Garhwal ==> True
# Mandal ==> True
# , ==> False
# Mahesh ==> True
# Chandra ==> True
# Mishra ==> True
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> True
# town ==> False
# . ==> False
# In ==> True
# its ==> False
# report ==> False
# dated ==> False
# May ==> True
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> True
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> True
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The title cases in the doc
#
# Joshimath
# The
# Commissioner
# Garhwal
# Mandal
# Mahesh
# Chandra
# Mishra
# Joshimath
# In
# May
# Amid
# Congress
#
#  The no of title cases: 13

# %% [markdown]
# ## Is it a quote?

# %%
# No of quotes in the documnt

q_count=0
for token in doc1:
    print(token,'==>',token.is_quote)
print('\n \n The quotes in the doc \n')
for token in doc1:
    if token.is_quote == True:
        q_count=q_count+1
        print(token)
print('\n The no of quotes:',q_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> False
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> True
# geologically ==> False
# unstable ==> False
# ” ==> True
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> False
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> False
# , ==> False
# 1976 ==> False
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The quotes in the doc
#
# “
# ”
#
#  The no of quotes: 2

# %% [markdown]
# ## Is it like a number

# %%
# No of Numbers in the documnt

n_count=0
for token in doc1:
    print(token,'==>',token.like_num)
print('\n \n The numbers in the doc \n')
for token in doc1:
    if token.like_num == True:
        n_count=n_count+1
        print(token)
print('\n The count of numbers:',n_count)
# Out:
# THE ==> False
# WRITING ==> False
# was ==> False
# on ==> False
# the ==> False
# wall ==> False
# — ==> False
# as ==> False
# early ==> False
# as ==> False
# almost ==> False
# half ==> False
# a ==> False
# century ==> False
# ago ==> False
# , ==> False
# when ==> False
# an ==> False
# 18 ==> True
# - ==> False
# member ==> False
# committee ==> False
# warned ==> False
# that ==> False
# the ==> False
# town ==> False
# of ==> False
# Joshimath ==> False
# is ==> False
# “ ==> False
# geologically ==> False
# unstable ==> False
# ” ==> False
# , ==> False
# and ==> False
# suggested ==> False
# several ==> False
# restrictions ==> False
# and ==> False
# remedial ==> False
# measures ==> False
# . ==> False
# The ==> False
# committee ==> False
# , ==> False
# under ==> False
# the ==> False
# chairmanship ==> False
# of ==> False
# then ==> False
# Commissioner ==> False
# , ==> False
# Garhwal ==> False
# Mandal ==> False
# , ==> False
# Mahesh ==> False
# Chandra ==> False
# Mishra ==> False
# , ==> False
# was ==> False
# set ==> False
# up ==> False
# to ==> False
# probe ==> False
# the ==> False
# cause ==> False
# of ==> False
# landslides ==> False
# and ==> False
# sinking ==> False
# of ==> False
# Joshimath ==> False
# town ==> False
# . ==> False
# In ==> False
# its ==> False
# report ==> False
# dated ==> False
# May ==> False
# 7 ==> True
# , ==> False
# 1976 ==> True
# , ==> False
# it ==> False
# suggested ==> False
# restrictions ==> False
# on ==> False
# heavy ==> False
# construction ==> False
# work ==> False
# , ==> False
# agriculture ==> False
# on ==> False
# slopes ==> False
# , ==> False
# felling ==> False
# of ==> False
# trees ==> False
# ; ==> False
# construction ==> False
# of ==> False
# pucca ==> False
# drainage ==> False
# to ==> False
# stop ==> False
# seepage ==> False
# of ==> False
# rainwater ==> False
# , ==> False
# proper ==> False
# sewage ==> False
# system ==> False
# , ==> False
# and ==> False
# cement ==> False
# blocks ==> False
# on ==> False
# river ==> False
# banks ==> False
# to ==> False
# prevent ==> False
# erosion ==> False
# . ==> False
# Amid ==> False
# the ==> False
# current ==> False
# crisis ==> False
# , ==> False
# the ==> False
# Congress ==> False
# and ==> False
# BJP ==> False
# are ==> False
# now ==> False
# blaming ==> False
# each ==> False
# other ==> False
# for ==> False
# failing ==> False
# to ==> False
# implement ==> False
# the ==> False
# recommendations ==> False
# of ==> False
# the ==> False
# report ==> False
# . ==> False
#
#
#  The numbers in the doc
#
# 18
# 7
# 1976
#
#  The count of numbers: 3

# %%
doc2=nlp(' 2 is the second lowest positive integer')

# %%
for token in doc2:
    print(token,'=>',token.like_num)
# Out:
#   => False
# 2 => True
# is => False
# the => False
# second => True
# lowest => False
# positive => False
# integer => False

# %%
for token in doc2:
    print(token,'=>',token.is_digit)
# Out:
#   => False
# 2 => True
# is => False
# the => False
# second => False
# lowest => False
# positive => False
# integer => False

# %% [markdown]
# ## Is it like a url?

# %%
doc3=nlp('The url of Times of India is www.timesofindia.com, which we tried to access')

# %%
for token in doc3:
    print(token.text,'==>',token.like_url)
# Out:
# The ==> False
# url ==> False
# of ==> False
# Times ==> False
# of ==> False
# India ==> False
# is ==> False
# www.timesofindia.com ==> True
# , ==> False
# which ==> False
# we ==> False
# tried ==> False
# to ==> False
# access ==> False

# %% [markdown]
# ## Is it like an Email ID?

# %%
doc4=nlp(' My Email ID is abc123@nmims.edu')

# %%
for token in doc4:
    print(token.text, '=>', token.like_email)
# Out:
#   => False
# My => False
# Email => False
# ID => False
# is => False
# abc123@nmims.edu => True

# %%
doc5=nlp(' My Email id is abc123@nmims.edu')

# %%
for token in doc5:
    print(token.text, '=>', token.like_email)
# Out:
#   => False
# My => False
# Email => False
# i => False
# d => False
# is => False
# abc123@nmims.edu => True

# %% [markdown]
# # Parts of Speech - POS

# %%
for token in doc1:
    print(token.text,'==>',token.pos_)
# Out:
# THE ==> DET
# WRITING ==> NOUN
# was ==> AUX
# on ==> ADP
# the ==> DET
# wall ==> NOUN
# — ==> PUNCT
# as ==> ADV
# early ==> ADV
# as ==> ADP
# almost ==> ADV
# half ==> DET
# a ==> DET
# century ==> NOUN
# ago ==> ADV
# , ==> PUNCT
# when ==> SCONJ
# an ==> DET
# 18 ==> NUM
# - ==> PUNCT
# member ==> NOUN
# committee ==> NOUN
# warned ==> VERB
# that ==> SCONJ
# the ==> DET
# town ==> NOUN
# of ==> ADP
# Joshimath ==> PROPN
# is ==> AUX
# “ ==> PUNCT
# geologically ==> ADV
# unstable ==> ADJ
# ” ==> PUNCT
# , ==> PUNCT
# and ==> CCONJ
# suggested ==> VERB
# several ==> ADJ
# restrictions ==> NOUN
# and ==> CCONJ
# remedial ==> ADJ
# measures ==> NOUN
# . ==> PUNCT
# The ==> DET
# committee ==> NOUN
# , ==> PUNCT
# under ==> ADP
# the ==> DET
# chairmanship ==> NOUN
# of ==> ADP
# then ==> ADV
# Commissioner ==> PROPN
# , ==> PUNCT
# Garhwal ==> PROPN
# Mandal ==> PROPN
# , ==> PUNCT
# Mahesh ==> PROPN
# Chandra ==> PROPN
# Mishra ==> PROPN
# , ==> PUNCT
# was ==> AUX
# set ==> VERB
# up ==> ADP
# to ==> PART
# probe ==> VERB
# the ==> DET
# cause ==> NOUN
# of ==> ADP
# landslides ==> NOUN
# and ==> CCONJ
# sinking ==> NOUN
# of ==> ADP
# Joshimath ==> PROPN
# town ==> NOUN
# . ==> PUNCT
# In ==> ADP
# its ==> PRON
# report ==> NOUN
# dated ==> VERB
# May ==> PROPN
# 7 ==> NUM
# , ==> PUNCT
# 1976 ==> NUM
# , ==> PUNCT
# it ==> PRON
# suggested ==> VERB
# restrictions ==> NOUN
# on ==> ADP
# heavy ==> ADJ
# construction ==> NOUN
# work ==> NOUN
# , ==> PUNCT
# agriculture ==> NOUN
# on ==> ADP
# slopes ==> NOUN
# , ==> PUNCT
# felling ==> NOUN
# of ==> ADP
# trees ==> NOUN
# ; ==> PUNCT
# construction ==> NOUN
# of ==> ADP
# pucca ==> NOUN
# drainage ==> NOUN
# to ==> PART
# stop ==> VERB
# seepage ==> NOUN
# of ==> ADP
# rainwater ==> NOUN
# , ==> PUNCT
# proper ==> ADJ
# sewage ==> NOUN
# system ==> NOUN
# , ==> PUNCT
# and ==> CCONJ
# cement ==> NOUN
# blocks ==> NOUN
# on ==> ADP
# river ==> NOUN
# banks ==> NOUN
# to ==> PART
# prevent ==> VERB
# erosion ==> NOUN
# . ==> PUNCT
# Amid ==> ADP
# the ==> DET
# current ==> ADJ
# crisis ==> NOUN
# , ==> PUNCT
# the ==> DET
# Congress ==> PROPN
# and ==> CCONJ
# BJP ==> PROPN
# are ==> AUX
# now ==> ADV
# blaming ==> VERB
# each ==> DET
# other ==> ADJ
# for ==> ADP
# failing ==> VERB
# to ==> PART
# implement ==> VERB
# the ==> DET
# recommendations ==> NOUN
# of ==> ADP
# the ==> DET
# report ==> NOUN
# . ==> PUNCT

# %%
spacy.explain('ADP')
# Out:
# 'adposition'

# %% [markdown]
# ## POS in a DF

# %%
cols=['Token','POS','Explain_POS','Tag','Explain_Tag']
cols
# Out:
# ['Token', 'POS', 'Explain_POS', 'Tag', 'Explain_Tag']

# %%
rows=[]
for token in doc1:
    row=token,token.pos_,spacy.explain(token.pos_),token.tag_,spacy.explain(token.tag_)
    rows.append(row)
rows
# Out:
# [(THE, 'DET', 'determiner', 'DT', 'determiner'),
#  (WRITING, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (was, 'AUX', 'auxiliary', 'VBD', 'verb, past tense'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (wall, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (—, 'PUNCT', 'punctuation', ':', 'punctuation mark, colon or ellipsis'),
#  (as, 'ADV', 'adverb', 'RB', 'adverb'),
#  (early, 'ADV', 'adverb', 'RB', 'adverb'),
#  (as, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (almost, 'ADV', 'adverb', 'RB', 'adverb'),
#  (half, 'DET', 'determiner', 'PDT', 'predeterminer'),
#  (a, 'DET', 'determiner', 'DT', 'determiner'),
#  (century, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (ago, 'ADV', 'adverb', 'RB', 'adverb'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (when, 'SCONJ', 'subordinating conjunction', 'WRB', 'wh-adverb'),
#  (an, 'DET', 'determiner', 'DT', 'determiner'),
#  (18, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (-, 'PUNCT', 'punctuation', 'HYPH', 'punctuation mark, hyphen'),
#  (member, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (committee, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (warned, 'VERB', 'verb', 'VBD', 'verb, past tense'),
#  (that,
#   'SCONJ',
#   'subordinating conjunction',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (town, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (Joshimath, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (is, 'AUX', 'auxiliary', 'VBZ', 'verb, 3rd person singular present'),
#  (“, 'PUNCT', 'punctuation', '``', 'opening quotation mark'),
#  (geologically, 'ADV', 'adverb', 'RB', 'adverb'),
#  (unstable,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (”, 'PUNCT', 'punctuation', "''", 'closing quotation mark'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (suggested, 'VERB', 'verb', 'VBD', 'verb, past tense'),
#  (several,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (restrictions, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (remedial,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (measures, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (The, 'DET', 'determiner', 'DT', 'determiner'),
#  (committee, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (under,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (chairmanship, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (then, 'ADV', 'adverb', 'RB', 'adverb'),
#  (Commissioner, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (Garhwal, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (Mandal, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (Mahesh, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (Chandra, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (Mishra, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (was, 'AUX', 'auxiliary', 'VBD', 'verb, past tense'),
#  (set, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (up, 'ADP', 'adposition', 'RP', 'adverb, particle'),
#  (to, 'PART', 'particle', 'TO', 'infinitival "to"'),
#  (probe, 'VERB', 'verb', 'VB', 'verb, base form'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (cause, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (landslides, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (sinking, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (Joshimath, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (town, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (In, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (its, 'PRON', 'pronoun', 'PRP$', 'pronoun, possessive'),
#  (report, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (dated, 'VERB', 'verb', 'VBN', 'verb, past participle'),
#  (May, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (7, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (1976, 'NUM', 'numeral', 'CD', 'cardinal number'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (it, 'PRON', 'pronoun', 'PRP', 'pronoun, personal'),
#  (suggested, 'VERB', 'verb', 'VBD', 'verb, past tense'),
#  (restrictions, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (heavy,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (construction, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (work, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (agriculture, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (slopes, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (felling, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (trees, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (;, 'PUNCT', 'punctuation', ':', 'punctuation mark, colon or ellipsis'),
#  (construction, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (pucca, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (drainage, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (to, 'PART', 'particle', 'TO', 'infinitival "to"'),
#  (stop, 'VERB', 'verb', 'VB', 'verb, base form'),
#  (seepage, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (rainwater, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (proper,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (sewage, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (system, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (cement, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (blocks, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (on, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (river, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (banks, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (to, 'PART', 'particle', 'TO', 'infinitival "to"'),
#  (prevent, 'VERB', 'verb', 'VB', 'verb, base form'),
#  (erosion, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer'),
#  (Amid,
#   'ADP',
#   'adposition',
#   'IN',
#   'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (current,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (crisis, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (,, 'PUNCT', 'punctuation', ',', 'punctuation mark, comma'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (Congress, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (and, 'CCONJ', 'coordinating conjunction', 'CC', 'conjunction, coordinating'),
#  (BJP, 'PROPN', 'proper noun', 'NNP', 'noun, proper singular'),
#  (are, 'AUX', 'auxiliary', 'VBP', 'verb, non-3rd person singular present'),
#  (now, 'ADV', 'adverb', 'RB', 'adverb'),
#  (blaming, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (each, 'DET', 'determiner', 'DT', 'determiner'),
#  (other,
#   'ADJ',
#   'adjective',
#   'JJ',
#   'adjective (English), other noun-modifier (Chinese)'),
#  (for, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (failing, 'VERB', 'verb', 'VBG', 'verb, gerund or present participle'),
#  (to, 'PART', 'particle', 'TO', 'infinitival "to"'),
#  (implement, 'VERB', 'verb', 'VB', 'verb, base form'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (recommendations, 'NOUN', 'noun', 'NNS', 'noun, plural'),
#  (of, 'ADP', 'adposition', 'IN', 'conjunction, subordinating or preposition'),
#  (the, 'DET', 'determiner', 'DT', 'determiner'),
#  (report, 'NOUN', 'noun', 'NN', 'noun, singular or mass'),
#  (., 'PUNCT', 'punctuation', '.', 'punctuation mark, sentence closer')]

# %%
import pandas as pd

token_df=pd.DataFrame(rows,columns=cols)
token_df
# Out:
#                Token    POS  Explain_POS  Tag  \
# 0                THE    DET   determiner   DT
# 1            WRITING   NOUN         noun   NN
# 2                was    AUX    auxiliary  VBD
# 3                 on    ADP   adposition   IN
# 4                the    DET   determiner   DT
# ..               ...    ...          ...  ...
# 142  recommendations   NOUN         noun  NNS
# 143               of    ADP   adposition   IN
# 144              the    DET   determiner   DT
# 145           report   NOUN         noun   NN
# 146                .  PUNCT  punctuation    .
#
#                                    Explain_Tag
# 0                                   determiner
# 1                       noun, singular or mass
# 2                             verb, past tense
# 3    conjunction, subordinating or preposition
# 4                                   determiner
# ..                                         ...
# 142                               noun, plural
# 143  conjunction, subordinating or preposition
# 144                                 determiner
# 145                     noun, singular or mass
# 146          punctuation mark, sentence closer
#
# [147 rows x 5 columns]

# %%
token_df['POS'].value_counts()
# Out:
# NOUN     37
# PUNCT    22
# ADP      18
# DET      14
# VERB     11
# PROPN    11
# ADV       7
# ADJ       7
# CCONJ     5
# AUX       4
# PART      4
# NUM       3
# SCONJ     2
# PRON      2
# Name: POS, dtype: int64
